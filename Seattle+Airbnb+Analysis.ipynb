# %%
# predict price?
# Can you describe the vibe of each Seattle neighborhood using listing descriptions?
# What are the busiest times of the year to visit Seattle? By how much do prices spike?
# Is there a general upward trend of both new Airbnb listings and total Airbnb visitors to Seattle?

# what kind of listing will get the best rating?
# what kind of listing is the most expensive?

# predict positive / negative comment? sentiment - https://docs.aws.amazon.com/comprehend/latest/dg/how-sentiment.html
# find out the vatiables relationships

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
#import seaborn as sns
# %matplotlib inline

# %%
# explore calendar data
df_cal = pd.read_csv('./seattle/calendar.csv')
df_cal.head()
# Out:
#    listing_id        date available   price
# 0      241032  2016-01-04         t  $85.00
# 1      241032  2016-01-05         t  $85.00
# 2      241032  2016-01-06         f     NaN
# 3      241032  2016-01-07         f     NaN
# 4      241032  2016-01-08         f     NaN

# %%
# explore listing data
df_listings = pd.read_csv('./seattle/listings.csv')
df_listings.head()
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0   241032   https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 1   953595   https://www.airbnb.com/rooms/953595  20160104002432   2016-01-04
# 2  3308979  https://www.airbnb.com/rooms/3308979  20160104002432   2016-01-04
# 3  7421966  https://www.airbnb.com/rooms/7421966  20160104002432   2016-01-04
# 4   278830   https://www.airbnb.com/rooms/278830  20160104002432   2016-01-04
#
#                                   name  \
# 0         Stylish Queen Anne Apartment
# 1   Bright & Airy Queen Anne Apartment
# 2  New Modern House-Amazing water view
# 3                   Queen Anne Chateau
# 4       Charming craftsman 3 bdm house
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
# 3  A charming apartment that sits atop Queen Anne...
# 4  Cozy family craftman house in beautiful neighb...
#
#                                                space  \
# 0  Make your self at home in this charming one-be...
# 1  Beautiful, hypoallergenic apartment in an extr...
# 2  Our house is modern, light and fresh with a wa...
# 3                                                NaN
# 4  Cozy family craftman house in beautiful neighb...
#
#                                          description experiences_offered  \
# 0  Make your self at home in this charming one-be...                none
# 1  Chemically sensitive? We've removed the irrita...                none
# 2  New modern house built in 2013.  Spectacular s...                none
# 3  A charming apartment that sits atop Queen Anne...                none
# 4  Cozy family craftman house in beautiful neighb...                none
#
#                                neighborhood_overview        ...         \
# 0                                                NaN        ...
# 1  Queen Anne is a wonderful, truly functional vi...        ...
# 2  Upper Queen Anne is a charming neighborhood fu...        ...
# 3                                                NaN        ...
# 4  We are in the beautiful neighborhood of Queen ...        ...
#
#   review_scores_value requires_license license jurisdiction_names  \
# 0                10.0                f     NaN         WASHINGTON
# 1                10.0                f     NaN         WASHINGTON
# 2                10.0                f     NaN         WASHINGTON
# 3                 NaN                f     NaN         WASHINGTON
# 4                 9.0                f     NaN         WASHINGTON
#
#   instant_bookable cancellation_policy  require_guest_profile_picture  \
# 0                f            moderate                              f
# 1                f              strict                              t
# 2                f              strict                              f
# 3                f            flexible                              f
# 4                f              strict                              f
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                f                              2
# 1                                t                              6
# 2                                f                              2
# 3                                f                              1
# 4                                f                              1
#
#   reviews_per_month
# 0              4.07
# 1              1.48
# 2              1.15
# 3               NaN
# 4              0.89
#
# [5 rows x 92 columns]

# %%
# explore reviews data
df_reviews = pd.read_csv('./seattle/reviews.csv')
df_reviews.head()
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0     7202016  38917982  2015-07-19     28943674        Bianca
# 1     7202016  39087409  2015-07-20     32440555         Frank
# 2     7202016  39820030  2015-07-26     37722850           Ian
# 3     7202016  40813543  2015-08-02     33671805        George
# 4     7202016  41986501  2015-08-10     34959538          Ming
#
#                                             comments
# 0  Cute and cozy place. Perfect location to every...
# 1  Kelly has a great room in a very central locat...
# 2  Very spacious apartment, and in a great neighb...
# 3  Close to Seattle Center and all it has to offe...
# 4  Kelly was a great host and very accommodating ...

# %%
print('calendar shape:', df_cal.shape)
print('listings shape:', df_listings.shape)
print('reviews shape:', df_reviews.shape)
# Out:
# calendar shape: (1393570, 4)
# listings shape: (3818, 92)
# reviews shape: (84849, 6)

# %%
# check missing data for calendar
np.sum(df_cal.isnull()).sort_values(ascending=False)
# Out:
# price         459028
# available          0
# date               0
# listing_id         0
# dtype: int64

# %%
# check missing data for listings
np.sum(df_listings.isnull()).sort_values(ascending=False)
# Out:
# license                             3818
# square_feet                         3721
# monthly_price                       2301
# security_deposit                    1952
# weekly_price                        1809
# notes                               1606
# neighborhood_overview               1032
# cleaning_fee                        1030
# transit                              934
# host_about                           859
# host_acceptance_rate                 773
# review_scores_accuracy               658
# review_scores_checkin                658
# review_scores_value                  656
# review_scores_location               655
# review_scores_cleanliness            653
# review_scores_communication          651
# review_scores_rating                 647
# reviews_per_month                    627
# first_review                         627
# last_review                          627
# space                                569
# host_response_time                   523
# host_response_rate                   523
# neighbourhood                        416
# xl_picture_url                       320
# thumbnail_url                        320
# medium_url                           320
# host_neighbourhood                   300
# summary                              177
#                                     ...
# availability_60                        0
# availability_90                        0
# availability_365                       0
# number_of_reviews                      0
# minimum_nights                         0
# requires_license                       0
# jurisdiction_names                     0
# instant_bookable                       0
# cancellation_policy                    0
# require_guest_profile_picture          0
# require_guest_phone_verification       0
# maximum_nights                         0
# extra_people                           0
# neighbourhood_group_cleansed           0
# calculated_host_listings_count         0
# city                                   0
# state                                  0
# market                                 0
# smart_location                         0
# country_code                           0
# country                                0
# longitude                              0
# guests_included                        0
# is_location_exact                      0
# room_type                              0
# accommodates                           0
# bed_type                               0
# amenities                              0
# price                                  0
# id                                     0
# Length: 92, dtype: int64

# %%
# check missing data for reviews
np.sum(df_reviews.isnull()).sort_values(ascending=False)
# Out:
# comments         17
# reviewer_name     0
# reviewer_id       0
# date              0
# id                0
# listing_id        0
# dtype: int64

# %%
#df_listings.hist()

# %% [markdown]
# ## What are the busiest times of the year to visit Seattle? By how much do prices spike?

# %%
# check the busiest period
df_cal['month'] = pd.to_datetime(df_cal['date']).dt.to_period('M')

# %%
df_cal.head()
# Out:
#    listing_id        date available   price   month
# 0      241032  2016-01-04         t  $85.00 2016-01
# 1      241032  2016-01-05         t  $85.00 2016-01
# 2      241032  2016-01-06         f     NaN 2016-01
# 3      241032  2016-01-07         f     NaN 2016-01
# 4      241032  2016-01-08         f     NaN 2016-01

# %%
# limit the data to 2016 only as there are few record in 2017
df_cal = df_cal[df_cal['date'] < '2017-01-01']

# convert the price to number
df_cal['price'] = df_cal[df_cal['price'].isnull() == False]['price'].apply(lambda x: float(x[1:].replace(',', '')))

# %%
# check number of data in the year for a listing_id
df_cal.groupby(['listing_id']).count()['available'].unique()

# we have only 363 days of data, the first 3 days in Jan-2016 is missing
# Out:
# array([363])

# %%
# get the availabe = 'f' for each day
df_available_f = df_cal[df_cal['available'] == 'f'].groupby(['month']).count()['listing_id'].reset_index(name="count")
df_available_f.head(12)
# Out:
#      month  count
# 0  2016-01  47665
# 1  2016-02  37401
# 2  2016-03  34420
# 3  2016-04  38503
# 4  2016-05  38387
# 5  2016-06  37296
# 6  2016-07  44136
# 7  2016-08  42011
# 8  2016-09  37294
# 9  2016-10  35920
# 10 2016-11  32760
# 11 2016-12  31297

# %%
# get the availabe = 't' for each day
# https://stackoverflow.com/questions/29836477/pandas-create-new-column-with-count-from-groupby
df_available_t = df_cal[df_cal['available'] == 't'].groupby(['month']).count()['listing_id'].reset_index(name="count")
df_available_t.head(12)
# Out:
#      month  count
# 0  2016-01  59239
# 1  2016-02  73321
# 2  2016-03  83938
# 3  2016-04  76037
# 4  2016-05  79971
# 5  2016-06  77244
# 6  2016-07  74222
# 7  2016-08  76347
# 8  2016-09  77246
# 9  2016-10  82438
# 10 2016-11  81780
# 11 2016-12  87061

# %%
df_cal['listing_id'].nunique()
# Out:
# 3818

# %%
# https://stackoverflow.com/questions/332289/how-do-you-change-the-size-of-figures-drawn-with-matplotlib
# https://stackoverflow.com/questions/44100429/plotting-period-series-in-matplotlib-pyplot
x = np.arange(0,len(df_available_f),1)
fig, ax = plt.subplots(1, 1, figsize=(12, 8))
ax.plot(x, df_available_f['count'])
ax.set_xticks(x)
ax.set_xticklabels(df_available_f['month'])
plt.title('Number of rented listing in 2016')
plt.show()

# %%
x = np.arange(0,len(df_available_t),1)
fig, ax = plt.subplots(1, 1, figsize=(12, 8))
ax.plot(x, df_available_t['count'])
ax.set_xticks(x)
ax.set_xticklabels(df_available_t['month'])
plt.title('Number of available listing in 2016')
plt.show()

# %%
df_available_t['count'] + df_available_f['count']
# Out:
# 0     106904
# 1     110722
# 2     118358
# 3     114540
# 4     118358
# 5     114540
# 6     118358
# 7     118358
# 8     114540
# 9     118358
# 10    114540
# 11    118358
# Name: count, dtype: int64

# %% [markdown]
# From the charts above, we can see the busiest period in 2016 is Jan-2016 and Jul-2016

# %% [markdown]
# ## Now the price. Plot some charts on the price changs during the year

# %%
# average price by month
df_month_price = df_cal.groupby(['month']).mean()['price'].reset_index(name="avg_price")
df_month_price.head(12)
# Out:
#      month   avg_price
# 0  2016-01  121.568409
# 1  2016-02  124.293927
# 2  2016-03  128.644488
# 3  2016-04  135.097005
# 4  2016-05  139.538183
# 5  2016-06  147.473137
# 6  2016-07  152.094150
# 7  2016-08  150.656594
# 8  2016-09  143.255949
# 9  2016-10  137.031939
# 10 2016-11  135.688738
# 11 2016-12  137.251835

# %%
x = np.arange(0,len(df_available_t),1)
fig, ax = plt.subplots(1, 1, figsize=(12, 8))
ax.plot(x, df_month_price['avg_price'])
ax.set_xticks(x)
ax.set_xticklabels(df_month_price['month'])
plt.title('Average price of listings in 2016')
plt.show()

# %%
# average price by listings
df_month_price = df_cal.groupby(['listing_id']).mean()['price'].reset_index(name="avg_price").sort_values(by='avg_price', ascending=False)
df_month_price.head()
# Out:
#       listing_id    avg_price
# 977      3308979  1304.816514
# 2673     7733192  1011.709497
# 1541     4825073  1000.000000
# 823      2720963   950.000000
# 1409     4464824   910.333333

# %% [markdown]
# We can see the average price is the highest in Jul-2016

# %% [markdown]
# ## Any Relationship between Rating and Price?

# %%
df_listings.sort_values(by=['review_scores_rating', 'number_of_reviews'], ascending=[False, False])
#df_listings.sort_values(by=['number_of_reviews'], ascending=[False])
# Out:
#             id                            listing_url       scrape_id  \
# 1094    706385    https://www.airbnb.com/rooms/706385  20160104002432
# 3581   1974131   https://www.airbnb.com/rooms/1974131  20160104002432
# 2107   5056580   https://www.airbnb.com/rooms/5056580  20160104002432
# 2619    948077    https://www.airbnb.com/rooms/948077  20160104002432
# 3715   4871348   https://www.airbnb.com/rooms/4871348  20160104002432
# 814    4757025   https://www.airbnb.com/rooms/4757025  20160104002432
# 895    1826155   https://www.airbnb.com/rooms/1826155  20160104002432
# 864    1772119   https://www.airbnb.com/rooms/1772119  20160104002432
# 1183   1260259   https://www.airbnb.com/rooms/1260259  20160104002432
# 2028   3543247   https://www.airbnb.com/rooms/3543247  20160104002432
# 517    2033191   https://www.airbnb.com/rooms/2033191  20160104002432
# 329    3050140   https://www.airbnb.com/rooms/3050140  20160104002432
# 888    2032805   https://www.airbnb.com/rooms/2032805  20160104002432
# 82     1956274   https://www.airbnb.com/rooms/1956274  20160104002432
# 547    4279578   https://www.airbnb.com/rooms/4279578  20160104002432
# 878    4387985   https://www.airbnb.com/rooms/4387985  20160104002432
# 2327   3258213   https://www.airbnb.com/rooms/3258213  20160104002432
# 3450   4485424   https://www.airbnb.com/rooms/4485424  20160104002432
# 1003   6475289   https://www.airbnb.com/rooms/6475289  20160104002432
# 2065   3968416   https://www.airbnb.com/rooms/3968416  20160104002432
# 3298   1856253   https://www.airbnb.com/rooms/1856253  20160104002432
# 1543   7451624   https://www.airbnb.com/rooms/7451624  20160104002432
# 2293   4461706   https://www.airbnb.com/rooms/4461706  20160104002432
# 3296   1777158   https://www.airbnb.com/rooms/1777158  20160104002432
# 3801   4524575   https://www.airbnb.com/rooms/4524575  20160104002432
# 904    7305969   https://www.airbnb.com/rooms/7305969  20160104002432
# 1851      9531      https://www.airbnb.com/rooms/9531  20160104002432
# 3371   3238295   https://www.airbnb.com/rooms/3238295  20160104002432
# 424    1715582   https://www.airbnb.com/rooms/1715582  20160104002432
# 1792   7563243   https://www.airbnb.com/rooms/7563243  20160104002432
# ...        ...                                    ...             ...
# 3606   6865696   https://www.airbnb.com/rooms/6865696  20160104002432
# 3609  10318171  https://www.airbnb.com/rooms/10318171  20160104002432
# 3618   9023202   https://www.airbnb.com/rooms/9023202  20160104002432
# 3620   7151093   https://www.airbnb.com/rooms/7151093  20160104002432
# 3635  10019082  https://www.airbnb.com/rooms/10019082  20160104002432
# 3637   9618016   https://www.airbnb.com/rooms/9618016  20160104002432
# 3650   5059981   https://www.airbnb.com/rooms/5059981  20160104002432
# 3662   7743727   https://www.airbnb.com/rooms/7743727  20160104002432
# 3668   6867053   https://www.airbnb.com/rooms/6867053  20160104002432
# 3669   9693230   https://www.airbnb.com/rooms/9693230  20160104002432
# 3675   8699046   https://www.airbnb.com/rooms/8699046  20160104002432
# 3677   6169489   https://www.airbnb.com/rooms/6169489  20160104002432
# 3685  10060674  https://www.airbnb.com/rooms/10060674  20160104002432
# 3686   9822848   https://www.airbnb.com/rooms/9822848  20160104002432
# 3690   9925458   https://www.airbnb.com/rooms/9925458  20160104002432
# 3706   9513636   https://www.airbnb.com/rooms/9513636  20160104002432
# 3717   7761509   https://www.airbnb.com/rooms/7761509  20160104002432
# 3720   9189391   https://www.airbnb.com/rooms/9189391  20160104002432
# 3730   8118110   https://www.airbnb.com/rooms/8118110  20160104002432
# 3741   8428825   https://www.airbnb.com/rooms/8428825  20160104002432
# 3743   3931346   https://www.airbnb.com/rooms/3931346  20160104002432
# 3745   6290509   https://www.airbnb.com/rooms/6290509  20160104002432
# 3780   7009282   https://www.airbnb.com/rooms/7009282  20160104002432
# 3781   9196007   https://www.airbnb.com/rooms/9196007  20160104002432
# 3792   9288840   https://www.airbnb.com/rooms/9288840  20160104002432
# 3800   5482204   https://www.airbnb.com/rooms/5482204  20160104002432
# 3802   8562314   https://www.airbnb.com/rooms/8562314  20160104002432
# 3815  10267360  https://www.airbnb.com/rooms/10267360  20160104002432
# 3816   9604740   https://www.airbnb.com/rooms/9604740  20160104002432
# 3817  10208623  https://www.airbnb.com/rooms/10208623  20160104002432
#
#      last_scraped                                 name  \
# 1094   2016-01-04     Lake Union view "Sky Cabin" apt.
# 3581   2016-01-04  Amazing Studio Apt on Capitol Hill!
# 2107   2016-01-04  Soaring Crane Luxury Garden Retreat
# 2619   2016-01-04  Capitol Hill Stylish Garden Cottage
# 3715   2016-01-04    Private Entrance Bedroom and Bath
# 814    2016-01-04    Charming and Private-AAA Location
# 895    2016-01-04   Seattle "Sweet Suite" Cherry Hill
# 864    2016-01-04   Cherry Hill Cozy, Budget Loft-Bed
# 1183   2016-01-04                    Zen Garden Oasis!
# 2028   2016-01-04     Spa retreat in vibrant Greenwood
# 517    2016-01-04     Green Lake VIEW 2 Bed 1 Bath Apt
# 329    2016-01-04     Cozy Private Greenlake Apartment
# 888    2016-01-04       Victorian Charm on Cherry Hill
# 82     2016-01-04      Sweet Ballard Apartment for Two
# 547    2016-01-04  Bright GreenLake studio - all yours
# 878    2016-01-04     Cozy 2BD Seattle Home w/ Hot Tub
# 2327   2016-01-04  Kayaks + Large Studio-Style Bedroom
# 3450   2016-01-04  View Home 3.7 mi from Pike Pl. Mkt.
# 1003   2016-01-04     Modern luxury unit near downtown
# 2065   2016-01-04  Enjoy West Seattle with Lovely View
# 3298   2016-01-04   Modern Vintage Eclectic in Ballard
# 1543   2016-01-04  2bed/2bath High Rise w/ View & Deck
# 2293   2016-01-04                'Streaming in Seattle
# 3296   2016-01-04  Amazing View, Large Room in Ballard
# 3801   2016-01-04        Comfortable Fremont Apartment
# 904    2016-01-04  Walkable, private Capitol Hill room
# 1851   2016-01-04  The Adorable Sweet Orange Craftsman
# 3371   2016-01-04  Brand New, Bright, Modern Apartment
# 424    2016-01-04     An  Old Charm in Central Seattle
# 1792   2016-01-04      Yurt Glamping in an Urban Oasis
# ...           ...                                  ...
# 3606   2016-01-04       Vintage light-filled apartment
# 3609   2016-01-04  Cozy basement room with shared bath
# 3618   2016-01-04         Capital Hill Home in Seattle
# 3620   2016-01-04     Seattle Explorer with double bed
# 3635   2016-01-04  Spacious 1BR Capitol Hill Apartment
# 3637   2016-01-04  Classic Home, Mid-City Neighborhood
# 3650   2016-01-04  Seattle Seahawks vs Packers Weekend
# 3662   2016-01-04  Cozy studio, great Fremont location
# 3668   2016-01-04  Wallingmont Apartment with Balcony!
# 3669   2016-01-04   Cozy home in the center of it all!
# 3675   2016-01-04    Primely Located Fremont Apartment
# 3677   2016-01-04                         Casa de Chet
# 3685   2016-01-04              In the heart of Fremont
# 3686   2016-01-04            Private room in 2 bed apt
# 3690   2016-01-04        Fremont guest room with futon
# 3706   2016-01-04  Modern&Upscale-walk to GOOGL &Adobe
# 3717   2016-01-04   420-Lovin' Loft, Skyline View+Yard
# 3720   2016-01-04   Sweet and Cozy 1 Bedroom Apartment
# 3730   2016-01-04           Cozy Wallingford Apartment
# 3741   2016-01-04   1Br Condo in the Heart of Fremont!
# 3743   2016-01-04                              Frelard
# 3745   2016-01-04     Modern, Sophisticated, 1 Bedroom
# 3780   2016-01-04                     Fremont Bungalow
# 3781   2016-01-04    Luxury Apartment in Artsy Fremont
# 3792   2016-01-04                           City Haven
# 3800   2016-01-04                       Six room suite
# 3802   2016-01-04   Cozy Craftsman in Heart of Fremont
# 3815   2016-01-04    Private apartment view of Lake WA
# 3816   2016-01-04    Amazing View with Modern Comfort!
# 3817   2016-01-04            Large Lakefront Apartment
#
#                                                 summary  \
# 1094  The Sky Cabin is a stunning, bright, and beaut...
# 3581  Big, beautiful, comfy studio apartment in a sw...
# 2107  Gorgeous professionally-designed 850 square fo...
# 2619  Small Space, Big Style, Spectacular Location w...
# 3715  A clean, quiet and comfortable bedroom and bat...
# 814       Relax and enjoy your visit to Seattle in t...
# 895   "Bed Baked and Beyond: Cherry Hill" is an eleg...
# 864       Our comfy double-bed loft is priced right ...
# 1183  Cozy, modern home, only steps away from 500+ a...
# 2028   Enjoy the experience of this luxurious spa re...
# 517   Modern, view apartment just steps from Green L...
# 329   Friendly, renovated, clean, comfortable 1 bedr...
# 888   A French Victorian double bed stylishly graces...
# 82    Located in the Sunset Hill/Ballard Area of Sea...
# 547   Half a block from Green Lake Park, this bright...
# 878   Our lovely 2 bedroom house is centrally locate...
# 2327  Kayak at Lake Washington, 1 mile from home. En...
# 3450  This 3 bedroom home with stunning views of dow...
# 1003  Newly renovated, 800 sq ft 1 BR lower level fl...
# 2065  Enjoy a stay in West Seattle nestled in a love...
# 3298  A private room in a home in the Ballard/Sunset...
# 1543  Enjoy our beautiful 2 bedroom, 2 bathroom apar...
# 2293  Come Airstreaming in Mt. Baker, one of Seattle...
# 3296  A lovely spacious room for 1 to 3 with a stunn...
# 3801  This lovely apartment is located on the lower ...
# 904   Brand new modern townhome with easy walking an...
# 1851  The Sweet Orange is a delightful and spacious ...
# 3371  Our newly renovated daylight-basement has 7.5-...
# 424   Bright, spacious private room in an old charm ...
# 1792  Glamour camping at its finest: A self containe...
# ...                                                 ...
# 3606  We live on the top floor of a vintage building...
# 3609  Includes full size bed, a coffee maker, desk a...
# 3618  This home is located in a leafy North Capital ...
# 3620  This cute room offers just enough space for a ...
# 3635  This cozy 1 bedroom, 1 bathroom apartment is l...
# 3637  This welcoming home is in the quiet residentia...
# 3650  Are you looking for a place to stay in Seattle...
# 3662  Great comfortable studio accommodates 2 people...
# 3668  This apartment is in a great area of Seattle, ...
# 3669  Our home is in a highly desirable are near maj...
# 3675  Our 1 bed 1 bath apartment is located in the h...
# 3677                                    Great location.
# 3685  - Fantastic view of the Olympics! (3rd story b...
# 3686  Private clean bedroom with a queen sized bed, ...
# 3690  Perfect for single traveler - plenty of closet...
# 3706  4-story upscale townhouse with rooftop deck an...
# 3717  Welcome! If you crave a local experience with ...
# 3720  This sweet basement apartment is right in betw...
# 3730  Our apartment is nestled right in-between the ...
# 3741  Modern, cozy apartment, centrally located in t...
# 3743                        between fremont and ballard
# 3745  This newly designed contemporary apartment sit...
# 3780  Hello and WELCOME! My home is nestled is locat...
# 3781  100% satisfaction from people we host online a...
# 3792  Vacationing in Seattle? Traveling for business...
# 3800         Seattle's most elegant and romantic lit...
# 3802  Our rare for its location, 2 bedroom and 1 bat...
# 3815  Very comfortable lower unit. Quiet, charming m...
# 3816  Cozy studio condo in the heart on Madison Park...
# 3817  All hardwood floors, fireplace, 65" TV with Xb...
#
#                                                   space  \
# 1094  Welcome to our light and airy "Sky Cabin" in t...
# 3581  "Dreampop Studio" is swanky... and it's big!  ...
# 2107  Welcome to my professionally designed luxury 8...
# 2619  Small Space, Big Style, Spectacular Location w...
# 3715  I do a fair amount of business travel and I tr...
# 814   This apartment is 1200 square feet and the ent...
# 895   A 1903, Victorian home with plenty of modern c...
# 864   Our truly, central home is grand in scale--we ...
# 1183  A modest 450 square feet, but layed out with p...
# 2028  New, comfortable, filled with high end finishe...
# 517   This 2 bedroom, 1 bath apartment will give you...
# 329   2-3 person, furnished apartment with own entra...
# 888   Our truly central home is grand in scale yet v...
# 82    I hope this space will make my guests feel lik...
# 547   Welcome to Green Lake, a neighborhood with the...
# 878   Our house is located on a small tree lined str...
# 2327  Students, Visitors, Newcomers, Workers, Worksh...
# 3450  Our house is a comfortable, affordable view ho...
# 1003  Our lower level flat of our 1926 Tudor home ha...
# 2065  The large bedroom comfortably accommodates two...
# 3298  A private room in a home in the Ballard/Sunset...
# 1543  This is a large two bedroom, two bathroom luxu...
# 2293  Living in an Airstream is a unique way to stay...
# 3296  The room has both a queen bed, and a twin bed ...
# 3801  Our recently renovated apartment is perfect fo...
# 904                                                 NaN
# 1851  The Sweet Orange invites you to stay and play,...
# 3371  Our newly renovated daylight-basement has 7.5-...
# 424   Easy access to downtown and anywhere within Se...
# 1792  We are happy and proud to present West Seattle...
# ...                                                 ...
# 3606                                                NaN
# 3609                                                NaN
# 3618                                                NaN
# 3620                                                NaN
# 3635  THE SPACE:  This spacious but cozy 1 bed, 1 ba...
# 3637  Looking for a comfortable and spacious home fo...
# 3650  Are you looking for a place to stay in Seattle...
# 3662                                                NaN
# 3668                                                NaN
# 3669                                                NaN
# 3675                                                NaN
# 3677                                                NaN
# 3685  My room is about a 12x12 with a full side fram...
# 3686                                                NaN
# 3690                                                NaN
# 3706  Upscale, modern townhome built in 2015 with pl...
# 3717  Are you ready for the Seattle experience? If y...
# 3720                                                NaN
# 3730  The place is cozy and equipped with everything...
# 3741  This 1 bedroom/1 bathroom condo is the perfect...
# 3743                                                NaN
# 3745  Luxurious and all new apartment in one of Seat...
# 3780  Throughout the weekdays, my personal assistant...
# 3781  I've just started offering this space, so you ...
# 3792                                                NaN
# 3800  Each suite is 900 square feet of luxury and el...
# 3802  In a land ruled by condos, it's hard to find a...
# 3815                                                NaN
# 3816  Fully furnished unit to accommodate most needs...
# 3817                                                NaN
#
#                                             description experiences_offered  \
# 1094  The Sky Cabin is a stunning, bright, and beaut...                none
# 3581  Big, beautiful, comfy studio apartment in a sw...                none
# 2107  Gorgeous professionally-designed 850 square fo...                none
# 2619  Small Space, Big Style, Spectacular Location w...                none
# 3715  A clean, quiet and comfortable bedroom and bat...                none
# 814       Relax and enjoy your visit to Seattle in t...                none
# 895   "Bed Baked and Beyond: Cherry Hill" is an eleg...                none
# 864       Our comfy double-bed loft is priced right ...                none
# 1183  Cozy, modern home, only steps away from 500+ a...                none
# 2028   Enjoy the experience of this luxurious spa re...                none
# 517   Modern, view apartment just steps from Green L...                none
# 329   Friendly, renovated, clean, comfortable 1 bedr...                none
# 888   A French Victorian double bed stylishly graces...                none
# 82    Located in the Sunset Hill/Ballard Area of Sea...                none
# 547   Half a block from Green Lake Park, this bright...                none
# 878   Our lovely 2 bedroom house is centrally locate...                none
# 2327  Kayak at Lake Washington, 1 mile from home. En...                none
# 3450  This 3 bedroom home with stunning views of dow...                none
# 1003  Newly renovated, 800 sq ft 1 BR lower level fl...                none
# 2065  Enjoy a stay in West Seattle nestled in a love...                none
# 3298  A private room in a home in the Ballard/Sunset...                none
# 1543  Enjoy our beautiful 2 bedroom, 2 bathroom apar...                none
# 2293  Come Airstreaming in Mt. Baker, one of Seattle...                none
# 3296  A lovely spacious room for 1 to 3 with a stunn...                none
# 3801  This lovely apartment is located on the lower ...                none
# 904   Brand new modern townhome with easy walking an...                none
# 1851  The Sweet Orange is a delightful and spacious ...                none
# 3371  Our newly renovated daylight-basement has 7.5-...                none
# 424   Bright, spacious private room in an old charm ...                none
# 1792  Glamour camping at its finest: A self containe...                none
# ...                                                 ...                 ...
# 3606  We live on the top floor of a vintage building...                none
# 3609  Includes full size bed, a coffee maker, desk a...                none
# 3618  This home is located in a leafy North Capital ...                none
# 3620  This cute room offers just enough space for a ...                none
# 3635  This cozy 1 bedroom, 1 bathroom apartment is l...                none
# 3637  This welcoming home is in the quiet residentia...                none
# 3650  Are you looking for a place to stay in Seattle...                none
# 3662  Great comfortable studio accommodates 2 people...                none
# 3668  This apartment is in a great area of Seattle, ...                none
# 3669  Our home is in a highly desirable are near maj...                none
# 3675  Our 1 bed 1 bath apartment is located in the h...                none
# 3677                                    Great location.                none
# 3685  - Fantastic view of the Olympics! (3rd story b...                none
# 3686  Private clean bedroom with a queen sized bed, ...                none
# 3690  Perfect for single traveler - plenty of closet...                none
# 3706  4-story upscale townhouse with rooftop deck an...                none
# 3717  Welcome! If you crave a local experience with ...                none
# 3720  This sweet basement apartment is right in betw...                none
# 3730  Our apartment is nestled right in-between the ...                none
# 3741  Modern, cozy apartment, centrally located in t...                none
# 3743                        between fremont and ballard                none
# 3745  This newly designed contemporary apartment sit...                none
# 3780  Hello and WELCOME! My home is nestled is locat...                none
# 3781  100% satisfaction from people we host online a...                none
# 3792  Vacationing in Seattle? Traveling for business...                none
# 3800         Seattle's most elegant and romantic lit...                none
# 3802  Our rare for its location, 2 bedroom and 1 bat...                none
# 3815  Very comfortable lower unit. Quiet, charming m...                none
# 3816  Cozy studio condo in the heart on Madison Park...                none
# 3817  All hardwood floors, fireplace, 65" TV with Xb...                none
#
#                                   neighborhood_overview        ...         \
# 1094  Eastlake is a very quiet, hidden little neighb...        ...
# 3581  We are just a block from dozens of quaint and ...        ...
# 2107  North Beacon Hill is a very diverse, welcoming...        ...
# 2619  *The location on the west slope of Capitol Hil...        ...
# 3715  The house is a 5 minute car ride North of down...        ...
# 814     Your location in the Harrison neighborhood i...        ...
# 895   Seattle's Cherry Hill neighborhood still refle...        ...
# 864   One of Seattle's oldest neighborhoods, the Cen...        ...
# 1183  Magnolia rocks!  Head down to "the village".. ...        ...
# 2028  Greenwood is a very walkable neighborhood with...        ...
# 517   Within a 15 minute walking distance to great r...        ...
# 329   People can walk to restaurants, movies, parks,...        ...
# 888   One of Seattle's oldest neighborhoods, the Cen...        ...
# 82    All the fun and interesting things there are t...        ...
# 547   The Green Lake neighborhood can't be beat! Not...        ...
# 878   The Central District is a popular and walkable...        ...
# 2327  I happily live in zip code 98118, the most div...        ...
# 3450  Magnolia is a very nice, quiet neighborhood cl...        ...
# 1003  Leschi is located on a hill just east of the d...        ...
# 2065  We are located up the hill from Lincoln Park, ...        ...
# 3298                                                NaN        ...
# 1543  Steps from the waterfront.  2 blocks from the ...        ...
# 2293  Stroll through our neighborhood of stately hom...        ...
# 3296  We are just around the corner from Sunset Hill...        ...
# 3801  Fremont is centrally located within the city a...        ...
# 904   Capitol Hill is a vibrant neighborhood with to...        ...
# 1851  The neighborhood is awesome!  Just far enough ...        ...
# 3371  Many shops, restaurants, coffee houses, bakeri...        ...
# 424                                                 NaN        ...
# 1792  The charming North Admiral District neighborho...        ...
# ...                                                 ...        ...
# 3606                                                NaN        ...
# 3609                                                NaN        ...
# 3618  All the homes are from the (phone number hidde...        ...
# 3620                                                NaN        ...
# 3635                                                NaN        ...
# 3637  Despite the quiet, leafy streets of this resid...        ...
# 3650  My home is located 6 miles north of Quest Fiel...        ...
# 3662                                                NaN        ...
# 3668                                                NaN        ...
# 3669                                                NaN        ...
# 3675                                                NaN        ...
# 3677                                                NaN        ...
# 3685  - Fremont has been called the Center of the Un...        ...
# 3686                                                NaN        ...
# 3690                                                NaN        ...
# 3706                                                NaN        ...
# 3717  The neighborhood has a diverse history, which ...        ...
# 3720                                                NaN        ...
# 3730  Being nestled between Green Lake, Fremont, and...        ...
# 3741  Nicknamed the "Center of the Universe," Fremon...        ...
# 3743                                                NaN        ...
# 3745  Fremont is one of Seattle's most popular neigh...        ...
# 3780                                                NaN        ...
# 3781                                                NaN        ...
# 3792                                                NaN        ...
# 3800  Chelsea Station Inn is walking distance to the...        ...
# 3802  I loved living here before we had 3 kids. The ...        ...
# 3815                                                NaN        ...
# 3816  Madison Park offers a peaceful slow pace upsca...        ...
# 3817                                                NaN        ...
#
#      review_scores_value requires_license license jurisdiction_names  \
# 1094                10.0                f     NaN         WASHINGTON
# 3581                10.0                f     NaN         WASHINGTON
# 2107                10.0                f     NaN         WASHINGTON
# 2619                10.0                f     NaN         WASHINGTON
# 3715                10.0                f     NaN         WASHINGTON
# 814                 10.0                f     NaN         WASHINGTON
# 895                 10.0                f     NaN         WASHINGTON
# 864                 10.0                f     NaN         WASHINGTON
# 1183                10.0                f     NaN         WASHINGTON
# 2028                10.0                f     NaN         WASHINGTON
# 517                 10.0                f     NaN         WASHINGTON
# 329                 10.0                f     NaN         WASHINGTON
# 888                 10.0                f     NaN         WASHINGTON
# 82                  10.0                f     NaN         WASHINGTON
# 547                 10.0                f     NaN         WASHINGTON
# 878                 10.0                f     NaN         WASHINGTON
# 2327                10.0                f     NaN         WASHINGTON
# 3450                10.0                f     NaN         WASHINGTON
# 1003                10.0                f     NaN         WASHINGTON
# 2065                10.0                f     NaN         WASHINGTON
# 3298                10.0                f     NaN         WASHINGTON
# 1543                10.0                f     NaN         WASHINGTON
# 2293                10.0                f     NaN         WASHINGTON
# 3296                10.0                f     NaN         WASHINGTON
# 3801                10.0                f     NaN         WASHINGTON
# 904                 10.0                f     NaN         WASHINGTON
# 1851                10.0                f     NaN         WASHINGTON
# 3371                10.0                f     NaN         WASHINGTON
# 424                 10.0                f     NaN         WASHINGTON
# 1792                10.0                f     NaN         WASHINGTON
# ...                  ...              ...     ...                ...
# 3606                 NaN                f     NaN         WASHINGTON
# 3609                 NaN                f     NaN         WASHINGTON
# 3618                 NaN                f     NaN         WASHINGTON
# 3620                 NaN                f     NaN         WASHINGTON
# 3635                 NaN                f     NaN         WASHINGTON
# 3637                 NaN                f     NaN         WASHINGTON
# 3650                 NaN                f     NaN         WASHINGTON
# 3662                 NaN                f     NaN         WASHINGTON
# 3668                 NaN                f     NaN         WASHINGTON
# 3669                 NaN                f     NaN         WASHINGTON
# 3675                 NaN                f     NaN         WASHINGTON
# 3677                 NaN                f     NaN         WASHINGTON
# 3685                 NaN                f     NaN         WASHINGTON
# 3686                 NaN                f     NaN         WASHINGTON
# 3690                 NaN                f     NaN         WASHINGTON
# 3706                 NaN                f     NaN         WASHINGTON
# 3717                 NaN                f     NaN         WASHINGTON
# 3720                 NaN                f     NaN         WASHINGTON
# 3730                 NaN                f     NaN         WASHINGTON
# 3741                 NaN                f     NaN         WASHINGTON
# 3743                 NaN                f     NaN         WASHINGTON
# 3745                 NaN                f     NaN         WASHINGTON
# 3780                 NaN                f     NaN         WASHINGTON
# 3781                 NaN                f     NaN         WASHINGTON
# 3792                 NaN                f     NaN         WASHINGTON
# 3800                 NaN                f     NaN         WASHINGTON
# 3802                 NaN                f     NaN         WASHINGTON
# 3815                 NaN                f     NaN         WASHINGTON
# 3816                 NaN                f     NaN         WASHINGTON
# 3817                 NaN                f     NaN         WASHINGTON
#
#      instant_bookable cancellation_policy  require_guest_profile_picture  \
# 1094                t              strict                              f
# 3581                t              strict                              t
# 2107                f            moderate                              f
# 2619                f            moderate                              f
# 3715                f            moderate                              f
# 814                 t            moderate                              f
# 895                 f              strict                              f
# 864                 f              strict                              f
# 1183                f            flexible                              f
# 2028                t            moderate                              f
# 517                 f            moderate                              f
# 329                 f            flexible                              f
# 888                 f              strict                              f
# 82                  f              strict                              f
# 547                 f            moderate                              f
# 878                 f              strict                              f
# 2327                f            moderate                              f
# 3450                t              strict                              f
# 1003                f              strict                              f
# 2065                f            moderate                              f
# 3298                f            flexible                              f
# 1543                t              strict                              f
# 2293                f            moderate                              f
# 3296                f              strict                              f
# 3801                f            moderate                              f
# 904                 f            moderate                              f
# 1851                f              strict                              f
# 3371                f            moderate                              f
# 424                 f            moderate                              f
# 1792                f            moderate                              f
# ...               ...                 ...                            ...
# 3606                f            flexible                              f
# 3609                f            flexible                              f
# 3618                f            flexible                              f
# 3620                f            moderate                              f
# 3635                f              strict                              f
# 3637                f            flexible                              f
# 3650                f            flexible                              f
# 3662                f            flexible                              f
# 3668                f            flexible                              f
# 3669                f            flexible                              f
# 3675                f            flexible                              f
# 3677                f            flexible                              f
# 3685                f            flexible                              f
# 3686                f            flexible                              f
# 3690                f            flexible                              f
# 3706                f              strict                              f
# 3717                f            flexible                              f
# 3720                f            flexible                              f
# 3730                f            moderate                              f
# 3741                f            moderate                              f
# 3743                f            flexible                              f
# 3745                f              strict                              f
# 3780                f            moderate                              f
# 3781                f              strict                              t
# 3792                f            flexible                              f
# 3800                f              strict                              f
# 3802                f            flexible                              f
# 3815                f            moderate                              f
# 3816                f            moderate                              f
# 3817                f            flexible                              f
#
#      require_guest_phone_verification calculated_host_listings_count  \
# 1094                                f                              2
# 3581                                t                              1
# 2107                                f                              1
# 2619                                f                              1
# 3715                                f                              1
# 814                                 f                              1
# 895                                 f                              5
# 864                                 f                              5
# 1183                                f                              1
# 2028                                f                              1
# 517                                 f                              1
# 329                                 f                              1
# 888                                 f                              5
# 82                                  f                              1
# 547                                 f                              1
# 878                                 f                              1
# 2327                                f                              2
# 3450                                f                              1
# 1003                                f                              1
# 2065                                f                              1
# 3298                                f                              1
# 1543                                f                              2
# 2293                                f                              2
# 3296                                f                              2
# 3801                                f                              1
# 904                                 f                              1
# 1851                                t                              2
# 3371                                f                              1
# 424                                 f                              1
# 1792                                f                              1
# ...                               ...                            ...
# 3606                                f                              1
# 3609                                f                              3
# 3618                                f                              1
# 3620                                f                              6
# 3635                                f                              1
# 3637                                f                              1
# 3650                                f                              1
# 3662                                f                              1
# 3668                                f                              1
# 3669                                f                              1
# 3675                                f                              1
# 3677                                f                              1
# 3685                                f                              1
# 3686                                f                              1
# 3690                                f                              1
# 3706                                f                              1
# 3717                                f                              2
# 3720                                f                              1
# 3730                                f                              1
# 3741                                f                              1
# 3743                                f                              1
# 3745                                f                              2
# 3780                                f                              1
# 3781                                t                              2
# 3792                                f                              1
# 3800                                f                              1
# 3802                                f                              1
# 3815                                f                              1
# 3816                                f                              1
# 3817                                f                              1
#
#      reviews_per_month
# 1094              4.85
# 3581              7.15
# 2107             10.95
# 2619              2.28
# 3715              6.20
# 814               6.92
# 895               3.11
# 864               2.77
# 1183              2.08
# 2028              4.00
# 517               2.76
# 329               2.75
# 888               2.13
# 82                2.11
# 547               3.25
# 878               3.29
# 2327              2.45
# 3450              2.72
# 1003              5.34
# 2065              1.89
# 3298              1.14
# 1543              5.27
# 2293              3.78
# 3296              1.09
# 3801              2.05
# 904               4.66
# 1851              0.54
# 3371              1.42
# 424               0.92
# 1792              4.75
# ...                ...
# 3606               NaN
# 3609               NaN
# 3618               NaN
# 3620               NaN
# 3635               NaN
# 3637               NaN
# 3650               NaN
# 3662               NaN
# 3668               NaN
# 3669               NaN
# 3675               NaN
# 3677               NaN
# 3685               NaN
# 3686               NaN
# 3690               NaN
# 3706               NaN
# 3717               NaN
# 3720               NaN
# 3730               NaN
# 3741               NaN
# 3743               NaN
# 3745               NaN
# 3780               NaN
# 3781               NaN
# 3792               NaN
# 3800               NaN
# 3802               NaN
# 3815               NaN
# 3816               NaN
# 3817               NaN
#
# [3818 rows x 92 columns]

# %%
df_listings[df_listings['id'] == 7733192]
# Out:
#           id                           listing_url       scrape_id  \
# 239  7733192  https://www.airbnb.com/rooms/7733192  20160104002432
#
#     last_scraped                                name  \
# 239   2016-01-04  Luxurious, Modern, Panoramic Views
#
#                                                summary  \
# 239  A  Contemporary Retreat with Stunning Views s ...
#
#                                                  space  \
# 239  Light, big windows, open spaces , views and co...
#
#                                            description experiences_offered  \
# 239  A  Contemporary Retreat with Stunning Views s ...                none
#
#                                  neighborhood_overview        ...         \
# 239  10 minutes walk to the restaurants and shoppin...        ...
#
#     review_scores_value requires_license license jurisdiction_names  \
# 239                 9.0                f     NaN         WASHINGTON
#
#     instant_bookable cancellation_policy  require_guest_profile_picture  \
# 239                f            moderate                              f
#
#     require_guest_phone_verification calculated_host_listings_count  \
# 239                                f                              1
#
#     reviews_per_month
# 239              2.67
#
# [1 rows x 92 columns]

# %%
df_listings.iloc[239]
# Out:
# id                                                                            7733192
# listing_url                                      https://www.airbnb.com/rooms/7733192
# scrape_id                                                              20160104002432
# last_scraped                                                               2016-01-04
# name                                               Luxurious, Modern, Panoramic Views
# summary                             A  Contemporary Retreat with Stunning Views s ...
# space                               Light, big windows, open spaces , views and co...
# description                         A  Contemporary Retreat with Stunning Views s ...
# experiences_offered                                                              none
# neighborhood_overview               10 minutes walk to the restaurants and shoppin...
# notes                                                                             NaN
# transit                             House is on a bus line to downtown. Walking is...
# thumbnail_url                       https://a0.muscache.com/ac/pictures/98306162/6...
# medium_url                          https://a0.muscache.com/im/pictures/98306162/6...
# picture_url                         https://a0.muscache.com/ac/pictures/98306162/6...
# xl_picture_url                      https://a0.muscache.com/ac/pictures/98306162/6...
# host_id                                                                      24633415
# host_url                                   https://www.airbnb.com/users/show/24633415
# host_name                                                                       David
# host_since                                                                 2014-12-08
# host_location                                      Seattle, Washington, United States
# host_about                          Me & my partner love to   travel the world on ...
# host_response_time                                                     within an hour
# host_response_rate                                                               100%
# host_acceptance_rate                                                             100%
# host_is_superhost                                                                   t
# host_thumbnail_url                  https://a2.muscache.com/ac/users/24633415/prof...
# host_picture_url                    https://a2.muscache.com/ac/users/24633415/prof...
# host_neighbourhood                                                         Queen Anne
# host_listings_count                                                                 4
#                                                           ...
# guests_included                                                                     4
# extra_people                                                                   $45.00
# minimum_nights                                                                      1
# maximum_nights                                                                    365
# calendar_updated                                                           a week ago
# has_availability                                                                    t
# availability_30                                                                    30
# availability_60                                                                    57
# availability_90                                                                    87
# availability_365                                                                  359
# calendar_last_scraped                                                      2016-01-04
# number_of_reviews                                                                  12
# first_review                                                               2015-08-23
# last_review                                                                2016-01-01
# review_scores_rating                                                              100
# review_scores_accuracy                                                             10
# review_scores_cleanliness                                                          10
# review_scores_checkin                                                              10
# review_scores_communication                                                        10
# review_scores_location                                                             10
# review_scores_value                                                                 9
# requires_license                                                                    f
# license                                                                           NaN
# jurisdiction_names                                                         WASHINGTON
# instant_bookable                                                                    f
# cancellation_policy                                                          moderate
# require_guest_profile_picture                                                       f
# require_guest_phone_verification                                                    f
# calculated_host_listings_count                                                      1
# reviews_per_month                                                                2.67
# Name: 239, Length: 92, dtype: object

# %%
df_listings.groupby('host_neighbourhood').count()['id'].reset_index(name="count")
# Out:
#             host_neighbourhood  count
# 0                         Alki     22
# 1                      Anaheim      7
# 2                Arbor Heights      3
# 3                     Atlantic     49
# 4                Baldwin Hills      1
# 5                      Ballard    210
# 6                     Belltown    254
# 7                Beverly Hills      1
# 8                  Bitter Lake     15
# 9                     Brighton      5
# 10                   Broadview     15
# 11                    Broadway      5
# 12                      Bryant     29
# 13                Capitol Hill    405
# 14                  Cedar Park      6
# 15   Central Business District     93
# 16           Central San Pedro      1
# 17        Clairemont Mesa East      1
# 18               Columbia City     61
# 19                  Crown Hill     21
# 20            Downtown Toronto      1
# 21                      Dunlap     14
# 22                East Village      1
# 23                    Eastlake     42
# 24                  Fauntleroy      9
# 25              Fenway/Kenmore      2
# 26                  First Hill     85
# 27                  Forestland      1
# 28                     Fremont    147
# 29                    Gatewood     18
# ..                         ...    ...
# 72               Olympic Hills     12
# 73               Phinney Ridge     52
# 74           Pike Place Market     31
# 75                   Pinehurst      1
# 76              Pioneer Square     11
# 77                 Portage Bay     14
# 78                  Queen Anne    189
# 79               Rainier Beach     18
# 80                     Ravenna    100
# 81                   Riverview      8
# 82                   Roosevelt     32
# 83                     Roxhill      1
# 84                Santa Monica      1
# 85                     Seaview      8
# 86                 Seward Park     27
# 87           South Beacon Hill      1
# 88              South Delridge      8
# 89            South Lake Union     16
# 90                  South Park      6
# 91                     Stevens     87
# 92                The Junction     39
# 93         University District     80
# 94             Victory Heights     13
# 95                  View Ridge      6
# 96               Waianae Coast      1
# 97                 Wallingford    134
# 98                   Wedgewood     16
# 99                    Westlake     12
# 100                 Windermere      9
# 101             Yesler Terrace     11
#
# [102 rows x 2 columns]
